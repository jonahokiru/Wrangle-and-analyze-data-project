# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Data Gathering
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv).

# %%
#Load the we rate dogs twitter achive data
import pandas as pd
twitter_archive_enhanced = pd.read_csv("twitter-archive-enhanced.csv")
#preview the first two rows of the dataset
twitter_archive_enhanced.sample(4)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2315  666691418707132416                    NaN                  NaN
# 978   749996283729883136                    NaN                  NaN
# 438   820013781606658049                    NaN                  NaN
# 1204  716080869887381504                    NaN                  NaN
#
#                       timestamp  \
# 2315  2015-11-17 18:56:35 +0000
# 978   2016-07-04 16:00:22 +0000
# 438   2017-01-13 21:04:55 +0000
# 1204  2016-04-02 01:52:38 +0000
#
#                                                  source  \
# 2315  <a href="http://twitter.com/download/iphone" r...
# 978   <a href="https://about.twitter.com/products/tw...
# 438   <a href="http://twitter.com/download/iphone" r...
# 1204  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 2315  This is Christoper. He is a spotted Penne. Can...                  NaN
# ...

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
import requests
url=("https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv")
x = requests.get(url, allow_redirects=True)
open('image_predictions.tsv', 'wb').write(x.content)
# Out:
# 335079

# %%
#Read the image_prediction.tsv in pandas
image_prediction = pd.read_csv("image_predictions.tsv", sep ='\t')
image_prediction.sample(20)
# Out:
#                 tweet_id                                            jpg_url  \
# 13    666082916733198337    https://pbs.twimg.com/media/CT5m4VGWEAAtKc8.jpg
# 1392  767122157629476866    https://pbs.twimg.com/media/CqVdiBJWIAEDZB4.jpg
# 1037  711998809858043904  https://pbs.twimg.com/tweet_video_thumb/CeGGkW...
# 190   669393256313184256    https://pbs.twimg.com/media/CUopnHPVEAAcL2o.jpg
# 878   698355670425473025    https://pbs.twimg.com/media/CbEOxQXW0AEIYBu.jpg
# 1668  813051746834595840    https://pbs.twimg.com/media/C0iKPZIXUAAbDYV.jpg
# 1064  715360349751484417    https://pbs.twimg.com/media/Ce14cOvWwAAcFJH.jpg
# 1896  850145622816686080    https://pbs.twimg.com/media/C8xS655XkAAv9vo.jpg
# 1775  828372645993398273    https://pbs.twimg.com/media/C374hb0WQAAIbQ-.jpg
# 1408  770293558247038976    https://pbs.twimg.com/media/CrCh5RgW8AAXW4U.jpg
# 544   677301033169788928    https://pbs.twimg.com/media/CWZBsjPWsAAZFFl.jpg
# ...

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = ''
consumer_secret = ''
access_token = ''
access_secret = ''


auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = twitter_archive_enhanced.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %%
#Load of the json data
import json
data = []
with open ('tweet_json.txt') as json_file:
    for line in json_file:
        data.append(json.loads(line))
#Build the dictionary and convert it to dataframe
tweet_list = []
for i in range(len(data)):
    tweet_id = data[i]['id']
    retweet_count = data[i]['retweet_count']
    favorite_count = data[i]['favorite_count']
    
    tweet_list.append({'tweet_id': tweet_id,
                       'retweet_count': retweet_count,
                       'favorite_count': favorite_count})
#The data frame
tweeter = pd.DataFrame(tweet_list, columns=['tweet_id', 'retweet_count', 'favorite_count'])
tweeter.sample(20)
# Out:
#                 tweet_id  retweet_count  favorite_count
# 454   816450570814898180           7470           28739
# 552   801285448605831168            773            5749
# 401   822244816520155136           9242           33136
# 272   838831947270979586          10062               0
# 165   858843525470990336           3029           14139
# 1549  687399393394311168            555            1753
# 507   808838249661788160           2868            9649
# 363   827600520311402496            865            7065
# 1402  697575480820686848            455            1895
# 1301  705898680587526145            497            2196
# 343   829878982036299777           4619               0
# 1070  736010884653420544           2711            7268
# 938   750383411068534784           1042            4274
# 84    876120275196170240           3905           24701
# 413   820837357901512704           6248               0
# 1240  709556954897764353            976            3029
# ...

# %% [markdown]
# ## Assessing Data

# %% [markdown]
# ## Asses the twitter erchived enhanced dataset visually.
# I begun by visualize the twitter_archive_enhanced dataset. In the dataset i come across some few tidness issue such as in the dog column, the dog none is invalid dog name. The other tidness issue i come across in the dataset is the columns of puppo, doggo, floofer and pupper should be merged into one column called dog stage with the variables puppo, doggo, floofer and pupper.

# %% [markdown]
# ## Asses the twitter erchived enhanced programatically.

# %%
#Check info of the dataset
twitter_archive_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# The columns of tweet_id, in_reply_to_status_id, in_reply_to_user_id, retweet_status_id, retweet_status_id_users, retweeted_status_timestamp and expanded urls some of their values is missing. Also  retweeted_status_timestamp datatype is a string instead of date time.

# %%
#Check for duplicates
twitter_archive_enhanced.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The twitter archived enhanced dataset had any duplicate records.

# %%
#Check for the missing values
twitter_archive_enhanced.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %% [markdown]
#  From the twitter archived enhanced dataset, the columns that had missing values were; in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id and retweeted_status_timestamp.

# %%
#Check for summary of the dataset
twitter_archive_enhanced.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %% [markdown]
# From the above summary of the dataset , its noted that the dataset had 2356 records

# %%
#check for the unique values in the dog name column
twitter_archive_enhanced['name'].unique()
#The number of unique values in the name column
len(twitter_archive_enhanced['name'].unique())
# Out:
# 957

# %% [markdown]
# The name column had 957 unique values

# %%
#check for the value counts of the rating denominator
twitter_archive_enhanced['rating_denominator'].value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %% [markdown]
# From the rating denominator column, it's noted that 10 had most records followed by 11 and 50 repectively.

# %%
#Check for the value counts of the numerator

# %%
twitter_archive_enhanced['rating_numerator'].value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %% [markdown]
# For the rating numerator the the value with most records is the 12, followed by 11 and 10 respectively.

# %%
#Check if the dog belong to more than one category of the dogs i.e doggo and paupper, or pupper and puppo, or floofer and puppo
twitter_archive_enhanced[(twitter_archive_enhanced['doggo']=='doggo') & (twitter_archive_enhanced['floofer']=='floofer')]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 200  854010172552949760                    NaN                  NaN
#
#                      timestamp  \
# 200  2017-04-17 16:34:26 +0000
#
#                                                 source  \
# 200  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 200  At first I thought this was a shy doggo, but i...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 200                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 200  https://twitter.com/dog_rates/status/854010172...                11
#
#      rating_denominator  name  doggo  floofer pupper puppo
# 200                  10  None  doggo  floofer   None  None

# %% [markdown]
# It's founded that the dog name None belong to more than category, that is the category of doggo and floofer.

# %%
#Check for the incorrect denominator ratings
twitter_archive_enhanced[twitter_archive_enhanced['rating_denominator'] !=10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 784   775096608509886464                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# 1254  710658690886586372                    NaN                  NaN
# 1274  709198395643068416                    NaN                  NaN
# ...

# %% [markdown]
# The incorrect ratings of the denominator that are not equal to 10 found are 15, 70, 7, 11, 150, 170,20, 50, 90, 80, 40, 130, 110, 16, 120 and 2.

# %% [markdown]
# ## Asessing the image_prediction dataset visually
# The column P1, P2, P3 represents the same item(dog breeds), the three columns should be merged into one column called dog breeds. The same applies to the columns P1_conf, P2_conf, P3_conf needs to be merged into dog conf column. The columns of P1_dog, P2_dog, P3_dog needs to dropped since they are of no importance in the dataset.

# %% [markdown]
# ## Asessing the image_prediction dataset programatically

# %%
#Check for the summary of the datast by describe function
image_prediction.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %% [markdown]
# The above out in the cell above displays the summary of the descriptive statistics of the image prediction dataset.

# %%
#Check for info of the image prediction dataset
image_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# The image prediction  dataset has the following column datatypes;  3 columns (boolean), 3 columns(float), 2 columns(int) and lastly 4 columns (objects).

# %%
#Check for the duplicates
image_prediction.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The image prediction had dataset had no duplicate records.

# %% [markdown]
# ## Asessing the tweeter dataset visually
# The dataset could be merged into the twitter_archive_enhanced dataset to form one dataset.

# %% [markdown]
# ## Asessing the tweeter dataset programatically

# %%
#Check for the datatypes and missing values
tweeter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2327 entries, 0 to 2326
# Data columns (total 3 columns):
# tweet_id          2327 non-null int64
# retweet_count     2327 non-null int64
# favorite_count    2327 non-null int64
# dtypes: int64(3)
# memory usage: 54.6 KB

# %% [markdown]
# All the three columns of the tweeter dataset are of the datatype integer.

# %%
#Check for duplicates
tweeter.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The twitter dataset has no duplicate records.

# %%
#Check the summary of the dataset
tweeter.describe()
# Out:
#            tweet_id  retweet_count  favorite_count
# count  2.327000e+03    2327.000000     2327.000000
# mean   7.417930e+17    2472.798023     7058.721100
# std    6.820795e+16    4187.963747    10969.201068
# min    6.660209e+17       1.000000        0.000000
# 25%    6.781394e+17     495.000000     1226.000000
# 50%    7.178418e+17    1149.000000     3053.000000
# 75%    7.986547e+17    2864.500000     8612.000000
# max    8.924206e+17   70799.000000   144988.000000

# %% [markdown]
# The above out displays the summary statistics of the tweeter dataset.

# %%
#check the shape of the data
tweeter.shape
# Out:
# (2327, 3)

# %% [markdown]
# The  tweeter dataset has 1771 records and 3 columns.

# %% [markdown]
# ### Quality issues
#
# ## twitter_archive_enhanced dataset
#
# 1. The columns of in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id,
#    expanded_urls and retweeted_status_timestamp have the missing values.
#
# 2. The invalid dog names e.g 'o' in the name column.
#
# 3. The erroneous value '0' in the column values of rating_denominator column.
#
# 4. The incorrect ratings (ratings_denominato !=10)
#
# 5. The column name floofer not well spelled, it should be spelled as floof instead of floofer.
#
# 6. In the text column, Some tweets has "\&amp" combined with ";" which is the html code to display  the ampersand.
#
#
#
#
#
# ## Image_prediction dataset
#
# 1. The "_" in the column values of p1, p2 and p3 and Inconsistence column values in P1, P2 and P3 columns. Some column values
#
#    in these columns begin with small letters while others with capital letter.
#
# 2. The datatype of the column of tweet_id needs to be string not int.(in the three datasets).

# %% [markdown]
# ### Tidiness issues
#
# ## Image prediction dataset
#
# 1.The three datasets needs to be merged into one fo further analysis
#
# ## twitter_archive_enhanced dataset
#
# 1.The column of doggo	floofer	pupper and puppo need to be merged into one column called dog_breeds with four variables of
#
# doggo floofer pupper and puppo.
#
# 2.The timestamp column needs to be splited into date and time.
#
# ## tweeter dataset
#
# 1.The dataset needs to be merged with others for further analysis

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %% [markdown]
# ## Make copy of the  three datasets

# %%
# Make copies of original pieces of data
twitter_archive_enhanced_clean = twitter_archive_enhanced.copy()
image_prediction_clean = image_prediction.copy()
tweeter_clean = tweeter.copy()

# %% [markdown]
# ### Issue #1:The columns of in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id,  expanded_urls and retweeted_status_timestamp have the missing values.

# %% [markdown]
# #### Define:  Drop the columns that contains the missing values.

# %% [markdown]
# #### Code

# %%
twitter_archive_enhanced_clean.dropna(axis = 'columns', how = 'any', inplace=True)

# %% [markdown]
# #### Test

# %%
twitter_archive_enhanced_clean.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %% [markdown]
# ### Issue# 2: invalid dog names e.g 'o' in the name column.

# %% [markdown]
# #### Define: Replace the invalid dog names in the name column wth un define

# %% [markdown]
# #### Code

# %%
#Import the counter module from the collection library
import collections
from collections import Counter
#firstly i will create alist named invalid_list to collect and store all invalid names that begins with small letter
#from the names column
invalid_list = []
for name in twitter_archive_enhanced_clean.name:
    if name.islower():
        invalid_list.append(name)
Counter(invalid_list)
# Out:
# Counter({'such': 1,
#          'a': 55,
#          'quite': 4,
#          'not': 2,
#          'one': 4,
#          'incredibly': 1,
#          'mad': 2,
#          'an': 7,
#          'very': 5,
#          'just': 4,
#          'my': 1,
#          'his': 1,
#          'actually': 2,
#          'getting': 2,
#          'this': 1,
#          'unacceptable': 1,
#          'all': 1,
#          'old': 1,
#          'infuriating': 1,
#          'the': 8,
#          'by': 1,
#          'officially': 1,
#          'life': 1,
#          'light': 1,
#          'space': 1})

# %%
#Replace the invalid name value  with the "Undefine" using the forloop and the replace string function
for name in twitter_archive_enhanced_clean['name']:
    if name in invalid_list:
        twitter_archive_enhanced_clean['name'] = twitter_archive_enhanced_clean['name']. replace('name', 'Undefine')

# %%
#Replace the None function with the undefine since it was not in the list since it begins with capital letter
twitter_archive_enhanced_clean['name'] = twitter_archive_enhanced_clean['name']. replace('None', 'Undefine')

# %% [markdown]
# #### Test

# %%
twitter_archive_enhanced_clean['name']. value_counts()
# Out:
# Undefine    745
# a            55
# Charlie      12
# Lucy         11
# Oliver       11
# Cooper       11
# Tucker       10
# Penny        10
# Lola         10
# Winston       9
# Bo            9
# Sadie         8
# the           8
# Buddy         7
# Toby          7
# Daisy         7
# an            7
# Bailey        7
# Scout         6
# Bella         6
# Jax           6
# Dave          6
# Leo           6
# Milo          6
# Jack          6
# Oscar         6
# Koda          6
# Rusty         6
# Stanley       6
# Gus           5
#            ...
# Humphrey      1
# Callie        1
# Sephie        1
# Doobert       1
# Vince         1
# Jaycob        1
# Saydee        1
# Tino          1
# Brady         1
# Brat          1
# Dug           1
# Rorie         1
# Juckson       1
# Emma          1
# Arya          1
# Halo          1
# Rodney        1
# Izzy          1
# Willie        1
# Darby         1
# Keet          1
# Rodman        1
# Augie         1
# Bayley        1
# ...

# %% [markdown]
# ### Issue#3: The erroneous value '0' in the column values of rating_denominator column

# %% [markdown]
# #### Define: Drop all the rows with the rating_denominator column value of  "0".

# %% [markdown]
# #### Code

# %%
#First i filter out the rows who's rating denominator column values are "0"
twitter_archive_enhanced_clean[twitter_archive_enhanced_clean['rating_denominator']== 0]
#Drop the filtered row
twitter_archive_enhanced_clean.drop(twitter_archive_enhanced_clean[twitter_archive_enhanced_clean['rating_denominator']== 0].index, 
                              inplace = True)

# %% [markdown]
# #### Test

# %%
twitter_archive_enhanced_clean[twitter_archive_enhanced_clean['rating_denominator']== 0]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ## Issue# 4: The column name floofer not well spelled, it should be spelled as floof instead of floofer

# %% [markdown]
# Define: Rename the column from floofer to floof

# %% [markdown]
# Code

# %%
twitter_archive_enhanced_clean.rename(columns={'floofer': 'floof'}, inplace=True)

# %% [markdown]
# Test

# %%
twitter_archive_enhanced_clean.head(2)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...                13
# 1  This is Tilly. She's just checking pup on you....                13
#
#    rating_denominator     name doggo floof pupper puppo
# 0                  10  Phineas  None  None   None  None
# 1                  10    Tilly  None  None   None  None

# %% [markdown]
# ## Issue# 5: In the text column, Some tweets has "\&amp" combined with ";" which is the html code to display  the ampersand.

# %% [markdown]
# Define:Change the html ampersand code from "&amp ;" to "&" in the text column, also remove '/n' the symbol of the new line and        lastely remove the ending url link.

# %% [markdown]
# Code

# %%
# change the "&amp" to "&"
twitter_archive_enhanced_clean['text'] = twitter_archive_enhanced_clean.text.str.replace("&amp;", "&")
# Romove "/n" the symbol for new line
twitter_archive_enhanced_clean['text'] = twitter_archive_enhanced_clean.text.str.replace("\n", " ")
# Remove ending url
twitter_archive_enhanced_clean['text'] = twitter_archive_enhanced_clean.text.str.replace(r"http\S+", "")
#Remove the white space
twitter_archive_enhanced_clean['text'] = twitter_archive_enhanced_clean.text.str.strip()

# %% [markdown]
# TEST

# %%
twitter_archive_enhanced_clean['text']
# Out:
# 0       This is Phineas. He's a mystical boy. Only eve...
# 1       This is Tilly. She's just checking pup on you....
# 2       This is Archie. He is a rare Norwegian Pouncin...
# 3       This is Darla. She commenced a snooze mid meal...
# 4       This is Franklin. He would like you to stop ca...
# 5       Here we have a majestic great white breaching ...
# 6       Meet Jax. He enjoys ice cream so much he gets ...
# 7       When you watch your owner call another dog a g...
# 8       This is Zoey. She doesn't want to be one of th...
# 9       This is Cassie. She is a college pup. Studying...
# 10      This is Koda. He is a South Australian decksha...
# 11      This is Bruno. He is a service shark. Only get...
# 12      Here's a puppo that seems to be on the fence a...
# 13      This is Ted. He does his best. Sometimes that'...
# 14      This is Stuart. He's sporting his favorite fan...
# 15      This is Oliver. You're witnessing one of his m...
# ...

# %% [markdown]
# ## Issue#6: The "_" in the column values of p1, p2 and p3 and Inconsistence column values in P1, P2 and P3 columns. Some column values in these columns begin with small letters while others with capital letter.

# %% [markdown]
# Define : Replace "_" with " " in the column values of p1, p2 and p3 and remove inconsistence by converting all column values to begin woth the capital letters

# %% [markdown]
# Code

# %%
#Replace the "_" with the " "
image_prediction_clean['p1'] = image_prediction_clean['p1'].str. replace("_", " ")
image_prediction_clean['p2'] = image_prediction_clean['p2'].str. replace("_", " ")
image_prediction_clean['p3'] = image_prediction_clean['p3'].str. replace("_", " ")

# %% [markdown]
# Test

# %%
print(image_prediction_clean['p1'])
print(image_prediction_clean['p2'])
print(image_prediction_clean['p3'])
# Out:
# 0            Welsh springer spaniel
# 1                           redbone
# 2                   German shepherd
# 3               Rhodesian ridgeback
# 4                miniature pinscher
# 5              Bernese mountain dog
# 6                        box turtle
# 7                              chow
# 8                     shopping cart
# 9                  miniature poodle
# 10                 golden retriever
# 11                    Gordon setter
# 12                     Walker hound
# 13                              pug
# 14                       bloodhound
# 15                            Lhasa
# 16                   English setter
# 17                              hen
# 18                 desktop computer
# 19                Italian greyhound
# 20                      Maltese dog
# 21                 three-toed sloth
# 22                               ox
# 23                 golden retriever
# 24                         malamute
# 25                       guinea pig
# ...

# %% [markdown]
# Code

# %%
#Apply the the str .upper string function to the three columns
image_prediction_clean['p1'] =image_prediction_clean['p1'].str.title()
image_prediction_clean['p2'] = image_prediction_clean['p2'].str.title()
image_prediction_clean['p3'] = image_prediction_clean['p3']. str.title()

# %% [markdown]
# Test

# %%
print(image_prediction_clean['p1'])
print(image_prediction_clean['p2'])
print(image_prediction_clean['p3'])
# Out:
# 0            Welsh Springer Spaniel
# 1                           Redbone
# 2                   German Shepherd
# 3               Rhodesian Ridgeback
# 4                Miniature Pinscher
# 5              Bernese Mountain Dog
# 6                        Box Turtle
# 7                              Chow
# 8                     Shopping Cart
# 9                  Miniature Poodle
# 10                 Golden Retriever
# 11                    Gordon Setter
# 12                     Walker Hound
# 13                              Pug
# 14                       Bloodhound
# 15                            Lhasa
# 16                   English Setter
# 17                              Hen
# 18                 Desktop Computer
# 19                Italian Greyhound
# 20                      Maltese Dog
# 21                 Three-Toed Sloth
# 22                               Ox
# 23                 Golden Retriever
# 24                         Malamute
# 25                       Guinea Pig
# ...

# %% [markdown]
# ## Issue# 7 : In the image prediction , twitter_archive_enhanced_clean and tweeter datasets, the datatype of the columns of tweet_id needs to be string not int.

# %% [markdown]
# Define: Convert the datatype of the tweet_id from integer to string in all the three datasets.

# %% [markdown]
# Code

# %%
#Convert the tweet id datatype from int to string
image_prediction_clean['tweet_id'] = image_prediction_clean['tweet_id'].astype(str)
twitter_archive_enhanced_clean['tweet_id'] = twitter_archive_enhanced_clean['tweet_id'].astype(str)
tweeter_clean['tweet_id'] = tweeter_clean['tweet_id'].astype(str)

# %% [markdown]
# Test

# %%
image_prediction_clean.dtypes
# Out:
# tweet_id     object
# jpg_url      object
# img_num       int64
# p1           object
# p1_conf     float64
# p1_dog         bool
# p2           object
# p2_conf     float64
# p2_dog         bool
# p3           object
# p3_conf     float64
# p3_dog         bool
# dtype: object

# %% [markdown]
# Test

# %%
twitter_archive_enhanced_clean.dtypes
# Out:
# tweet_id              object
# timestamp             object
# source                object
# text                  object
# rating_numerator       int64
# rating_denominator     int64
# name                  object
# doggo                 object
# floof                 object
# pupper                object
# puppo                 object
# dtype: object

# %% [markdown]
# Test

# %%
tweeter_clean.dtypes
# Out:
# tweet_id          object
# retweet_count      int64
# favorite_count     int64
# dtype: object

# %% [markdown]
# ## Issue#8: updating the incorrect ratings

# %% [markdown]
# Define: Replace the incorrect denominator ratings with 10.

# %% [markdown]
# Code

# %%
#Use the replace function to replace the incorrect ratings

# twitter_archive_enhanced_clean['rating_denominator'].replace(to_replace =9, value = 10, inplace = True)
twitter_archive_enhanced_clean['rating_denominator'].replace({15:10, 70:10, 7:10, 11:10, 150:10, 170:10,
                                                             20:10, 50:10, 90:10, 80:10, 40:10, 130:10, 
                                                             110:10, 16:10, 120:10, 2:10}, inplace=True)

# %% [markdown]
# Test

# %%
twitter_archive_enhanced_clean[twitter_archive_enhanced_clean['rating_denominator'] !=10]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, rating_numerator, rating_denominator, name, doggo, floof, pupper, puppo]
# Index: []

# %% [markdown]
# ## Data cleaning on the tidness issue

# %% [markdown]
# ## issue# 1:The columns of doggo floofer pupper and puppo needs to be combined into one column called dog_stage with four variables of doggo floofer pupper and puppo.

# %% [markdown]
# Deine : Combine the four columns using str.cat function

# %% [markdown]
# Code

# %%
#use the assign function to insert the column and column values
twitter_archive_enhanced_clean['Dog_Stage'] = twitter_archive_enhanced_clean['doggo'].str.cat(twitter_archive_enhanced_clean['floof']).str.cat(
twitter_archive_enhanced_clean['pupper']).str.cat(twitter_archive_enhanced_clean['puppo'])

# %%
#Summary of the dog stage column
twitter_archive_enhanced_clean['Dog_Stage'].value_counts()
# Out:
# NoneNoneNoneNone        1975
# NoneNonepupperNone       245
# doggoNoneNoneNone         83
# NoneNoneNonepuppo         29
# doggoNonepupperNone       12
# NoneflooferNoneNone        9
# doggoflooferNoneNone       1
# doggoNoneNonepuppo         1
# Name: Dog_Stage, dtype: int64

# %%
#since the stage name has repeated it self several time  we replace it with appropriate stage name using the dictionary below
appropriate_name = {'NoneNoneNoneNone': 'None', 'NoneNonepupperNone': 'pupper', 'doggoNoneNoneNone':'doggo',
                 
                 'NoneNoneNonepuppo':'puppo', 'doggoNonepupperNone':'doggopupper', 'NoneflooferNoneNone':'floofer',
                 'doggoflooferNoneNone':'doggofloofer', 'doggoNoneNonepuppo': 'doggopuppo'}

# %%
#Use map function to replace the appropriate name dictionnary key  with its  value
twitter_archive_enhanced_clean['Dog_Stage'] = twitter_archive_enhanced_clean['Dog_Stage'].map(appropriate_name)

# %% [markdown]
# Test

# %%
twitter_archive_enhanced_clean['Dog_Stage'].value_counts()
# Out:
# None            1975
# pupper           245
# doggo             83
# puppo             29
# doggopupper       12
# floofer            9
# doggopuppo         1
# doggofloofer       1
# Name: Dog_Stage, dtype: int64

# %% [markdown]
# ## Issue#3: The timestamp the date and time are combined.

# %% [markdown]
# Define: SPlit the timestamp column into date and time column respectively.

# %% [markdown]
# Code

# %%
twitter_archive_enhanced_clean['Date'] = pd.to_datetime(twitter_archive_enhanced_clean['timestamp']).dt.date
twitter_archive_enhanced_clean['Time'] = pd.to_datetime(twitter_archive_enhanced_clean['timestamp']).dt.time

# %% [markdown]
# Test

# %%
twitter_archive_enhanced_clean.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floof', 'pupper', 'puppo',
#        'Dog_Stage', 'Date', 'Time'],
#       dtype='object')

# %% [markdown]
# ## Issue#2: The three datasets needs to be merged into one for further Analysis.

# %% [markdown]
# Define : Use the merge function to merge the three datasets on the id column into one.

# %% [markdown]
# Code

# %%
#Merge the Twitter_archived_clean with the image_prediction_clean to form clean data
Clean_data = twitter_archive_enhanced_clean.merge(image_prediction_clean, on = 'tweet_id', how= 'right')
Clean_data.head(2)
#merge the clean data with the twitter data to form the Clean_data_final
Clean_data_final = Clean_data.merge(tweeter, on = 'tweet_id', how = 'right')
Clean_data_final.head(2)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...              13.0
# 1  This is Tilly. She's just checking pup on you....              13.0
#
#    rating_denominator     name doggo floof pupper      ...         p1_conf  \
# 0                10.0  Phineas  None  None   None      ...        0.097049
# 1                10.0    Tilly  None  None   None      ...        0.323581
#
#   p1_dog        p2   p2_conf p2_dog        p3   p3_conf  p3_dog retweet_count  \
# 0  False     Bagel  0.085851  False    Banana  0.076110   False          7014
# ...

# %% [markdown]
# Test

# %%
Clean_data_final.head(3)
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...              13.0
# 1  This is Tilly. She's just checking pup on you....              13.0
# 2  This is Archie. He is a rare Norwegian Pouncin...              12.0
#
#    rating_denominator     name doggo floof pupper      ...         p1_conf  \
# 0                10.0  Phineas  None  None   None      ...        0.097049
# 1                10.0    Tilly  None  None   None      ...        0.323581
# ...

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
Clean_data_final.to_csv("twitter_archive_master.csv", encoding = 'utf-8', index = False)

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
#Read the saved dataset using pandas library
df =pd.read_csv('twitter_archive_master.csv')

# %%
#Preview the dataset columns
df.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floof', 'pupper', 'puppo',
#        'Dog_Stage', 'Date', 'Time', 'jpg_url', 'img_num', 'p1', 'p1_conf',
#        'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog',
#        'retweet_count', 'favorite_count'],
#       dtype='object')

# %% [markdown]
# ### Insights:
# 1.I want to know about the dog rating and the retweet count. so that i learn more  on how the rating of the dog influences retweet count.
#
# 2.I would also want to find out more about the dog stage ,and how it influences the  retweets counts.
#
#
# 3.The realtionship between retweet count and favourite count. And also to get the time with the most retweet counts and favourite counts.

# %% [markdown]
# ### Visualization

# %%
#Preview the final dataset
df.sample(2)
# Out:
#                 tweet_id                  timestamp  \
# 1699  672609152938721280  2015-12-04 02:51:33 +0000
# 739   756275833623502848  2016-07-21 23:53:04 +0000
#
#                                                  source  \
# 1699  <a href="http://twitter.com/download/iphone" r...
# 739   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  rating_numerator  \
# 1699  This is Caryl. Likes to get in the microwave. ...               9.0
# 739   When ur older siblings get to play in the deep...              10.0
#
#       rating_denominator      name doggo floof pupper      ...        \
# 1699                10.0     Caryl  None  None   None      ...
# 739                 10.0  Undefine  None  None   None      ...
#
#        p1_conf p1_dog             p2   p2_conf p2_dog          p3   p3_conf  \
# 1699  0.981946  False     Rotisserie  0.007472  False  Television  0.005881
# ...

# %% [markdown]
# ## 1. I want to know about the dog rating and the retweeting status. so that i learn more on how the rating of the dog influences its  retweet count.

# %%
#Import the neccessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Define the function.

# %%
#Define the correlation plot function, to be used to plot bivariate correlations.
def cor(col1, col2, data):
    results= sns.regplot(x=col1, y=col2, data=df, scatter_kws = {"color": "blue"}, line_kws = {"color": "black"})
    return results

# %%
#Plot the histogram of the rating numerator
df['rating_numerator'].hist()
plt.title("Numerator ratings")
plt.xlabel('Num ratings')
plt.ylabel('No of num ratings')
plt.show()

# %% [markdown]
# The most of the ratings is between 10 to 20.

# %%
#Plot the histogram of the retweet status
df['retweet_count'].hist()
plt.title("Retweet Count")
plt.xlabel('Retweet Count')
plt.ylabel('No of retweet count')
plt.show()

# %% [markdown]
# Most of  the retweet count is between 0 to 500

# %%
#Scatteter plot of the reltionship between the dog ratings and retweet counts
print(cor("rating_numerator", "retweet_count", df))
plt.title("rating numerator vs retweet count")
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5,1,'rating numerator vs retweet count')

# %% [markdown]
# The relationship between the retweet count and the ratings of the dog is a positive correlation.

# %% [markdown]
# ## 2. I would also want to find out more about the dog stage ,and how it influences the  retweets counts.

# %%
#Bar plot of the dog stages
df['Dog_Stage'].value_counts().plot(kind='bar')
plt.title("Dog Stage")
plt.xlabel('Dog Stages')
plt.ylabel('No of counts')
plt.show()

# %% [markdown]
# Most of the dogs were in the stage of None.

# %%
#Plot the scatter plot to display the relationship between the dog stage and retweet counts
plt.scatter(x=df['retweet_count'], y=df['Dog_Stage'])
plt.title('Dog stage vs Retweet stage')
plt.ylabel('Dog stage')
plt.xlabel('Retweet count')
plt.show()

# %% [markdown]
# Each dog stage had different retweet count. The dog stage with the most retweet count was doggo, None and puppo respectively.

# %% [markdown]
# ## 3.The realtionship between retweet count and favourite count.

# %%
#Plot the scatter plot between retweet count and favourite count
print(cor('retweet_count', 'favorite_count', df))
plt.title('Retweet count vs Favourite count')
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5,1,'Retweet count vs Favourite count')

# %% [markdown]
# The relationship between the retweet count and the favourite count is a positive correlation.
