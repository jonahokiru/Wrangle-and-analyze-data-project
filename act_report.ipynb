# %% [markdown]
# ## Report: act_report
#
# ### Introduction
# In the project, I obtain the insights by analysis and visualization of the merged dataset , that was obtain by cleaning and
#
# merging the following dataset; twitter-archive-enhanced.csv, image_predictions.tsv and the twitter dataset from the twitter
#
# API. In my analysis of the dataset i will focus on the following dog ratings, retweet count, dog stage and fovourite count.

# %% [markdown]
# #### dog ratings vs retweet counts.

# %% [markdown]
# ![download4.png](attachment:download4.png)
#
#
# From the visualization above, I have conclude the following. Firstly, the correlation between the dog rating and the retweet
#
# count is positve. This implies when the dog ratings increase there's also an increase in the retweet counts. The second
#
# conclusion i have derived from the visualization is that the number of retweet counts increases exponentially as the ratings of
#
# the dog increases from 0 to 20, there after the number of retweet counts remain constant as the ratings of the dog increases.

# %% [markdown]
# #### Dog stage

# %% [markdown]
# ![download2.png](attachment:download2.png)
# From the visualization above i have note that; The dog stage with the most counts is the None, while doggofloofer is the dog
#
# stage with the least counts. The second insight derived from the visualization is that the counts of the dog stages decreases
#
# steadly from the None to doggofloofer and lastley , all the dog stages except None had the counts less than 250.

# %% [markdown]
# #### Retweet count  vs Fovourite count.

# %% [markdown]
# ![download5.png](attachment:download5.png)
#
# From the visualization above, the following insights is noted; Firstly, the relationship between the retweet count and the favourite count is a positive correlation. This implies that the counts of favourite counts increases as the retweet counts increases.
